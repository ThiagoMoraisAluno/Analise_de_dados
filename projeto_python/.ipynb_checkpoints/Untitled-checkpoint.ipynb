# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('vgsales.csv', sep=',')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df = pd.read_csv('vgsales.csv', sep=',')

# Verifique se há valores ausentes no dataframe
print(vendas.isnull().sum())
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df = df.fillna(0)

# %%
'''
generos de video games q mais vendem
'''
vendas.groupby('Genre').count()
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action        3316  3316      3316  3316       3309      3316      3316
# Adventure     1286  1286      1286  1286       1282      1286      1286
# Fighting       848   848       848   848        846       848       848
# Misc          1739  1739      1739  1739       1712      1739      1739
# Platform       886   886       886   886        884       886       886
# Puzzle         582   582       582   582        581       582       582
# Racing        1249  1249      1249  1249       1248      1249      1249
# Role-Playing  1488  1488      1488  1488       1486      1488      1488
# Shooter       1310  1310      1310  1310       1308      1310      1310
# Simulation     867   867       867   867        863       867       867
# Sports        2346  2346      2346  2346       2343      2346      2346
# Strategy       681   681       681   681        678       681       681
#
# ...

# %%
# Agrupar as vendas globais por jogo
games_sales = df.groupby('Name')['Global_Sales'].sum().reset_index()

# Ordenar os jogos pelo total de vendas
games_sales.sort_values('Global_Sales', ascending=False, inplace=True)

# Selecionar os 10 jogos com as maiores vendas
game_sales = games_sales[:10]

# Plotar o gráfico de barras
game_sales.plot(kind='bar', x='Name', y='Global_Sales', legend=False)


# Adicionar rótulos e título ao gráfico
plt.figure(figsize=(15,5))
plt.xlabel('Jogos')
plt.ylabel('Vendas globais (em milhões)')
plt.title('Top 10 jogos mais vendidos')
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
games_year = df.groupby('Year')['Global_Sales'].sum().reset_index()


games_year.sort_values('Global_Sales', ascending=False, inplace=True)

game_year = games_year[:10]

# Plotar o gráfico de barras
game_year.plot(kind='bar', x='Year', y='Global_Sales')


# Adicionar rótulos e título ao gráfico
plt.figure(figsize=(15,5))
plt.xlabel('Jogos')
plt.ylabel('Vendas globais (em milhões)')
plt.title('Top 10 jogos mais vendidos')


# Exibir o gráfico
plt.show()

# %%
#genero de games que mais venderam
genero = df.groupby('Genre').count().Year.sort_values(ascending=False)
plt.bar(genero.index, genero.values)
plt.xticks(rotation=45)
plt.show()
# Agrupar as vendas globais por jogo
games = df.groupby('Publisher')['JP_Sales'].sum().reset_index()

# Ordenar os jogos pelo total de vendas
games.sort_values('JP_Sales', ascending=False, inplace=True)

# Selecionar os 10 jogos com as maiores vendas
game = games[:10]

# Plotar o gráfico de barras
game.plot(kind='bar', x='Publisher', y='JP_Sales', legend=False)


# Adicionar rótulos e título ao gráfico
plt.figure(figsize=(15,5))
plt.xlabel('Jogos')
plt.ylabel('Vendas globais (em milhões)')
plt.title('Top 10 jogos mais vendidos')
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Soma das plantaformas mais usadas na coluna 'global_sales'
platform = df.groupby('Platform').sum(numeric_only=True).Global_Sales.sort_values(ascending=False)
plt.bar(platform.index, platform.values)
plt.xticks(rotation=60)
plt.show()
